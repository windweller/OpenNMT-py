# %% [markdown]
# ## Quality Visualize
#
# Instead of relying solely on BLEU score, we can load in generated prediction file, and map back to the test.
#
# We randomly visualize 200 examples.

# %%
src_test = []
tgt_test = []

with open('/home/anie/OpenNMT-py/data/src-test.txt', 'r') as f:
    for line in f:
        src_test.append(line.strip())

with open('/home/anie/OpenNMT-py/data/tgt-test.txt', 'r') as f:
    for line in f:
        tgt_test.append(line.strip())

# %%
def load_model(path):
    tgt_test = []
    with open(path, 'r') as f:
        for line in f:
            tgt_test.append(line.strip())
    return tgt_test

# %%
best_model_tgt = load_model('/home/anie/OpenNMT-py/save/because_transformer_sep5/dissent_step_80000_pred.txt')

# %%
def display(best_model_tgt, i=0, sample=100):
    for idx in range(i, i+sample):
        print("gold src: {}".format(src_test[idx][:-1] + 'because'))
        print("gold tgt: {}".format(tgt_test[idx]))
        print("gen tgt: {}".format(best_model_tgt[idx]))
        print("------------")

# %%
display(best_model_tgt)
# Out:
# gold src: The stamp would undercut post office revenue in the future because
# gold tgt: It would no longer get a financial gain when it raised rates .
# gen tgt: It would be difficult to attract new customers .
# ------------
# gold src: What , there s no such thing as failure because
# gold tgt: For me the most important thing in life is family .
# gen tgt: It is nt .
# ------------
# gold src: Many have resisted buying LEDs because
# gold tgt: They think they have to replace all their lights with kits for about $ 50 a pop .
# gen tgt: They are not sure how much they will cost .
# ------------
# gold src: Essentially , Wachovia was forced to write down the value of these assets because
# gold tgt: They were considered overvalued compared with the market value -- or what Wells Fargo was willing to pay .
# gen tgt: It was unable to sell them .
# ------------
# gold src: A beautician is refusing to move her car despite racking up nearly 300 in tickets because
# gold tgt: She claims a ' bullying ' council turned up unannounced and painted double yellow lines outside her home .
# gen tgt: She is ' too fat .
# ------------
# gold src: Weak inflation also tends to feed into slow growth in household incomes , , while also causing employees to lower their expectations for future wage growth because
# gold tgt: It crunches the profit margins of employers .
# gen tgt: It means they are spending more .
# ------------
# gold src: But the tight fishing restrictions probably wo n ' t be lifted anytime soon , the report said because
# gold tgt: The stocks of some fish , such as the Gulf of Maine cod and white hake , still remain at record low stock levels .
# gen tgt: The industry is still in its infancy .
# ------------
# gold src: The impact is limited because
# gold tgt: Some of those branch chiefs must be promoted to oversee others who become investigators .
# gen tgt: The government has already set up a reserve for the new fiscal year .
# ------------
# gold src: Crime control will be essential at Cabrini , Lane says , . because
# gold tgt: `` I wo n ' t be able to persuade working families to move in unless they feel safe .
# gen tgt: '' it 's a very dangerous area .
# ------------
# gold src: Who attended the meeting with Mr. Hun Sen and spoke on the condition of anonymity because
# gold tgt: He was not authorized to disclose the discussions publicly also disputed the statement .
# gen tgt: The meeting was private .
# ------------
# gold src: Finch 's name came up because
# gold tgt: It primarily wanted a heavy hitter in Twenty20 , but hopefully one who could also feature in its four - day County Championship matches as well .
# gen tgt: He was born in Canada .
# ------------
# gold src: Making his first start because
# gold tgt: Craig Ochs was feeling the effects of a concussion .
# gen tgt: He was n ' t feeling well .
# ------------
# gold src: Tell lies all the time to keep themselves away from all the troubles they may get into because
# gold tgt: They are homosexuals living in that country .
# gen tgt: They are so desperate .
# ------------
# gold src: As President Obama pointed out just last year , '' government will never run the way Silicon Valley runs because
# gold tgt: By definition , democracy is messy .
# gen tgt: It 's too big .
# ------------
# gold src: N ' t play well because
# gold tgt: Borussia Dortmund played better than us Roberto Mancini .
# gen tgt: We were n ' t good enough .
# ------------
# gold src: Evacuating them was not expected to take place until early Saturday because
# gold tgt: The water level has started rising again and renewed flooding is blocking the exit route , French television station LCI reported .
# gen tgt: They were still in the process of being released from prison .
# ------------
# gold src: Where I had to get myself back mentally because
# gold tgt: I was really mentally out of it .
# gen tgt: I was n ' t playing .
# ------------
# gold src: Chen is believed to be resting in Qinhuangdao , a seaside resort east of Beijing and is not expected to be tried because
# gold tgt: Apparently the party feels it would be too embarrassing .
# gen tgt: He is a danger to the public .
# ------------
# gold src: Chips are in demand because
# gold tgt: They are used in just about all electronic devices , from irons to sophisticated computers .
# gen tgt: Just they are cheap .
# ------------
# gold src: I d love the rematch against Garcia because
# gold tgt: I know deep down I m a better fighter than him .
# gen tgt: I think he s a great champion .
# ------------
# gold src: The state was being paralyzed because
# gold tgt: All of your opponents were filing these lawsuits .
# gen tgt: The government had not been able to provide the funds needed to pay for the construction of the dam .
# ------------
# gold src: I accept my punishment because
# gold tgt: I know what I did was wrong .
# gen tgt: I am a Muslim .
# ------------
# gold src: He will be done with six innings of work because
# gold tgt: He is due up second in the next inning .
# gen tgt: He is a good bowler .
# ------------
# gold src: You check the foreign office travel advice for any country you 're travelling to because
# gold tgt: This will make mention of any potential scams the foreign office are aware of .
# gen tgt: You may not be able to get a visa .
# ------------
# gold src: But the advantages are prized right now because
# gold tgt: These bonds -- often found in the municipal bond market -- tend to be resistant to some of the usual ill effects of rising interest rates .
# gen tgt: They are so easy to use .
# ------------
# gold src: He plans to attend the closing ceremony and to carry out ceremonial duties because
# gold tgt: London is host for the 2012 Olympics .
# gen tgt: He is not a member of the ceremony .
# ------------
# gold src: The timing of the deployment is unclear , in part because
# gold tgt: At least some of those forces were originally destined for Turkey , whose parliament on Saturday rejected a plan for the deployment of US forces there .
# gen tgt: The United States has yet to ratify the treaty .
# ------------
# gold src: We will all be able to move there soon because
# gold tgt: The United States sent a few astronauts to the moon .
# gen tgt: We have a lot of work to do .
# ------------
# gold src: As it is , he says , it all worked out fine because
# gold tgt: In spite of being '' a very sleepless two years , my wife is a superhero .
# gen tgt: He was able to do it himself .
# ------------
# gold src: '' It will be counterproductive , because
# gold tgt: People wo n ' t take the risk to go and unlock the gas and then you wo n ' t have any .
# gen tgt: It will encourage more people to come to the country .
# ------------
# gold src: ' We are extremely sorry for the delayed communications of last week , ' a Secret Cinema statement said because
# gold tgt: This is partly founders tend to have a strong emotional attachment to their creation .
# gen tgt: It 's a great opportunity to make a movie that 's not just about the movie .
# ------------
# gold src: Would likely be done in several stages `` because
# gold tgt: The structure of the shareholding is very complicated .
# gen tgt: The situation is so fluid .
# ------------
# gold src: We ca n ' t have a best - case scenario because
# gold tgt: Danny Manning is n ' t coming back .
# gen tgt: We have n ' t got the right answer .
# ------------
# gold src: The nearby fans enjoyed , urging the Lakers to beat the Suns because
# gold tgt: I 'm getting tired of this .
# gen tgt: They were the only team that could beat the Lakers .
# ------------
# gold src: Where the two narratives join up because
# gold tgt: There is real fear , inside and outside the zone .
# gen tgt: They are so different .
# ------------
# gold src: It survives and prospers because
# gold tgt: Otherwise we might as well grow moss in unsurprising Omaha .
# gen tgt: It is a good product .
# ------------
# gold src: The Wallabies looked tired and started hanging off us . because
# gold tgt: We were going at them and eventually we managed to get those three points .
# gen tgt: We were n ' t playing .
# ------------
# gold src: For me it 's the perfect place to live , I love the great outdoors and it 's quick to get to the coast because
# gold tgt: I love my sport .
# gen tgt: It 's so beautiful .
# ------------
# gold src: That banned his most threatening challenger , Rally leader Alassane Ouattara , from running for president because
# gold tgt: He is only half - Ivorian .
# gen tgt: He was born in Burkina Faso .
# ------------
# gold src: People are better off in the stadium because
# gold tgt: They are more likely to get food and water .
# gen tgt: They have a better chance of winning .
# ------------
# gold src: It 's nice to train with the men because
# gold tgt: I can learn something from them .
# gen tgt: They 're the ones who are going to be the ones who are going to be the ones who are going to be the ones who are going to be the ones who are going to be the ones who are going to be the next next generation .
# ------------
# gold src: To understand in part because
# gold tgt: Women often do n ' t even know they have miscarried if it happens in the first trimester .
# gen tgt: It 's a very difficult thing to do .
# ------------
# gold src: The couple were arrested on Tuesday for allegedly planting drugs in the car of a volunteer at their child 's school , according to the Irvine Police Department because
# gold tgt: They thought the parent volunteer `` was not properly supervising '' their son .
# gen tgt: They refused to pay for a . .
# ------------
# gold src: So many of us survived , but just did n ' t know when because
# gold tgt: We were all aware that it was going to happen .
# gen tgt: We were able to get out of the way .
# ------------
# gold src: He s not in , whose name he ca nt reveal because
# gold tgt: ' I might not have time to finish it .
# gen tgt: He fears for his safety .
# ------------
# gold src: All in all , this would n ' t be so hard to take because
# gold tgt: Growth at too fast a pace leads to inflation , eroding both the buying power of workers and the stability of governments .
# gen tgt: I 'm a woman .
# ------------
# gold src: '' I made comics because
# gold tgt: It was an anti - intellectual behavior .
# gen tgt: I wanted to be a writer .
# ------------
# gold src: A high - speed ferry service from Staten Island to midtown Manhattan will be canceled after the last scheduled trip on July 31 because
# gold tgt: It has not drawn enough passengers to break even .
# gen tgt: The storm has washed away the snow .
# ------------
# gold src: Be waiting for an ambulance because
# gold tgt: There are n ' t enough resources .
# gen tgt: They were so exhausted .
# ------------
# gold src: N ' t been back on a horse since that fall because
# gold tgt: My record company is not very keen on the idea of me injuring myself .
# gen tgt: I 've been so busy .
# ------------
# gold src: '' I voted for Bush . because
# gold tgt: That 's the name you heard a lot of talk about , `` Facundo said .
# gen tgt: I thought he was the best person for the job .
# ------------
# gold src: I 'm sticking to that because
# gold tgt: I think it is incredibly important for the long term progress of the Scottish Labour party that I can credibly point to an alternative to austerity .
# gen tgt: I think it 's important .
# ------------
# gold src: But , Olivia did slightly live in her shadow because
# gold tgt: Emily was the sort of child who lit up a room .
# gen tgt: She was n ' t wearing a seatbelt .
# ------------
# gold src: '' She 's hardworking , but makes it look so easy , `` he says , because
# gold tgt: She 's an utter pro who really does her homework .
# gen tgt: She 's a good dancer .
# ------------
# gold src: He should have left three American basketball players imprisoned in China because
# gold tgt: He did not like the comments made by one of their parents .
# gen tgt: He was a communist .
# ------------
# gold src: The cyst removal operation was chosen because
# gold tgt: It is simple and does not put the patient in danger .
# gen tgt: It was the only one that could prevent the spread of the disease .
# ------------
# gold src: So I owe a lot to the S and C and the physios because
# gold tgt: I would n ' t be here today without them .
# gen tgt: They 've been my biggest rivals .
# ------------
# gold src: '' Powell 's mission has succeeded , because
# gold tgt: Sharon 's plan is succeeding ... Occupation forces have not withdrawn and the massacres have continued .
# gen tgt: It has been able to train and train the enemy to fight against terrorism .
# ------------
# gold src: This became a self - fulfilling prophecy , Mutter writes , . because
# gold tgt: '' the authors of BNOB either missed the catch-22 logic of this or knew it and pretended they did n ' t .
# gen tgt: '' the world is a world that is not a world that is n ' t a world that is n ' t a world .
# ------------
# gold src: The Comcast deal collapsed because
# gold tgt: Regulators worried that it could impede online video competitors while giving Comcast too much power over the nation 's high - speed Internet access .
# gen tgt: The two sides could not agree on a price .
# ------------
# gold src: The lives of 15 of the patients represented in the petition -- including a teenager with lupus and a child suffering from cancer -- were in jeopardy because
# gold tgt: Treatment was not available in Gaza .
# gen tgt: The agency failed to follow proper procedures .
# ------------
# gold src: It happened that way because
# gold tgt: Lehman had just failed and everybody was freaked out about the possibility of a rolling collapse of the entire financial system .
# gen tgt: I was n ' t there .
# ------------
# gold src: '' We are setting plans for an assessment boycott in place because
# gold tgt: USS members have made it clear they are unconvinced by the employers '' arguments as well .
# gen tgt: We are not satisfied with the results of the elections .
# ------------
# gold src: It 's one of the most exciting developments in the treatment of arthritis in 25 years because
# gold tgt: We potentially will be able to treat people for their pain and inflammation without them suffering the side effects .
# gen tgt: It 's so new .
# ------------
# gold src: Jennings shot his father because
# gold tgt: He was feeling '' disrespected .
# gen tgt: He was angry at him for not being able to pay for his wife 's wedding .
# ------------
# gold src: Perhaps the student was so good because
# gold tgt: Thursday was n ' t the first time he acted as a moderator .
# gen tgt: He was so good at it .
# ------------
# gold src: Today the S2 makes this list because
# gold tgt: It 's simply such a cheap , excellent device .
# gen tgt: It 's the most recent .
# ------------
# gold src: Now he has his party 's nomination and the criticism has subsided over his role in the Iran - Contra scandal and his citation for contempt of Congress because
# gold tgt: Perhaps his detractors recognize they can do only so much to stop North .
# gen tgt: The U.S. Supreme Court has ruled that he is a federal agent .
# ------------
# gold src: , '' people 's lives were getting worse because
# gold tgt: The government was `` unjust and selfish .
# gen tgt: The government was not doing enough to combat the disease .
# ------------
# gold src: Morgan is not currently affected by the RFU 's stance because
# gold tgt: His current Scarlets contract was already in place when the policy came into force but his next move must be to England .
# gen tgt: He is not playing in the NRL .
# ------------
# gold src: The airport had hoped to establish such a stepping stone by this summer because
# gold tgt: It enables Scottish passengers to make one - stop long - haul journeys to the east rather than two if they travelled via European hubs .
# gen tgt: It was a '' very good time .
# ------------
# gold src: When people feel more control , it helps -LRB- them -RRB- feel better because
# gold tgt: They feel they 're more in charge .
# gen tgt: They know what they are doing .
# ------------
# gold src: According to a high - ranking police official close to the investigation , Lawrence was most likely able to leave through the doors because
# gold tgt: Someone was coming into the maternity ward at the same time .
# gen tgt: He was a police officer .
# ------------
# gold src: She was very fat with us because
# gold tgt: I neglected to exercise her and we fed her way too much .
# gen tgt: She was so fat .
# ------------
# gold src: '' Sadly '' is the word because
# gold tgt: Unless you are one of the few who genuinely love wind and rain , its arrival brings a distinct dip of glumness that hits you in the stomach .
# gen tgt: It is so difficult to understand .
# ------------
# gold src: But I am confident because
# gold tgt: We have more experience and that will show on Wednesday .
# gen tgt: I know I have done it .
# ------------
# gold src: The skittering and fizzing that takes place happens because
# gold tgt: The surface is super - hot - about twice as hot as the liquid 's boiling point .
# gen tgt: The . is a . .
# ------------
# gold src: Then he has to stay in shape because
# gold tgt: He wo n ' t be playing the first four games .
# gen tgt: He 's a great player .
# ------------
# gold src: '' The idea girls do n ' t like science because
# gold tgt: They have less innate talent for science is for me completely laughable .
# gen tgt: They think it 's too science .
# ------------
# gold src: Who acts in the interests of the people because
# gold tgt: It is accountable to them .
# gen tgt: They are the ones who are going to be the ones who will be the ones who will be the ones who will be the ones who will be the ones who will be the ones who will be the ones who will be the next next generation .
# ------------
# gold src: He wo n ' t get into the race for the Democratic presidential nomination because
# gold tgt: He does n ' t want to battle Sen. Hillary Clinton .
# gen tgt: He 's not a Mormon .
# ------------
# gold src: '' It makes all the difference in the world for us because
# gold tgt: We 're only around for six to eight weeks and we need as much visibility as possible .
# gen tgt: We are a country that has been in the forefront of the fight against terrorism .
# ------------
# gold src: But they wound up being drawn to meet this early because
# gold tgt: Williams is seeded only 28th , a reflection of her lower - than - usual ranking as a result of nearly a year 's absence from the tour because of a series of health scares .
# gen tgt: They were so excited about the new technology .
# ------------
# gold src: '' At several shelters , we are already turning away people -- and the cold weather has not even set in yet because
# gold tgt: There is no room .
# gen tgt: We have not received any reports of a typhoon .
# ------------
# gold src: Who spoke on condition of anonimity because
# gold tgt: He was not authorized to talk to the press .
# gen tgt: He was not authorized to speak to the media .
# ------------
# gold src: Would stop short of vigorously fighting the bill because
# gold tgt: It also contains funding for public schools and public charter schools that she supports .
# gen tgt: It was '' a big issue .
# ------------
# gold src: I 'm glad about all this because
# gold tgt: It allows me to feel such uncontrollable rage that no amount of reasonable argument will ever temper it .
# gen tgt: I 'm a very proud man .
# ------------
# gold src: This is at least in part because
# gold tgt: Many have experienced good care .
# gen tgt: The . is so much more than a . .
# ------------
# gold src: It probably was the key point in the game because
# gold tgt: We were making a nice run .
# gen tgt: We were n ' t able to get the ball back .
# ------------
# gold src: Which we have been for the last few years because
# gold tgt: We do respond quickly to set backs .
# gen tgt: We have had to fight for the title .
# ------------
# gold src: He has experienced a rapid uptick in playing time because
# gold tgt: The team 's top two point guards are injured .
# gen tgt: He has been playing well .
# ------------
# gold src: It 's a catch-22 situation because
# gold tgt: Industrialists are wary of investing in the state and generating jobs precisely because of continuing conflict .
# gen tgt: The . is not a good fit .
# ------------
# gold src: I must be going soft because
# gold tgt: I was also impressed with a ref on Tuesday .
# gen tgt: I 'm not a soft .
# ------------
# gold src: While attempting to remove the large Burmese python from the 2-foot - wide pipe Saturday , he was forced to stun the animal because
# gold tgt: It was so angry , the Bradenton -LRB- Fla. -RRB- .
# gen tgt: It was too big to be moved .
# ------------
# gold src: Cheaper prices drove computers out of the walls of these big companies because
# gold tgt: You suddenly did n ' t need all that money anymore .
# gen tgt: They were cheaper than the ones that were being used .
# ------------
# gold src: The victim was only saved because
# gold tgt: The dog turned on the former lifeguard .
# gen tgt: He was wearing a seatbelt .
# ------------
# gold src: '' Doing something like that is easy because
# gold tgt: You 're dictated to .
# gen tgt: I 'm not a big fan of the show .
# ------------
# gold src: It would be prime land because
# gold tgt: It is slightly elevated with views across Commonwealth Park .
# gen tgt: It was the first place in the world to be seen .
# ------------
# gold src: It has gained unusual force , as many rape victims do because
# gold tgt: The woman and her family have made their complaints public rather than keeping silent .
# gen tgt: It is often carried out by men .
# ------------
# gold src: '' We have to be aggressive and combative because
# gold tgt: They are solid up front .
# gen tgt: We have to fight for the title .
# ------------
